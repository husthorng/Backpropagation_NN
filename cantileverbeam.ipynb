# %% [markdown]
# <a href="https://colab.research.google.com/github/husthorng/Backpropagation_NN/blob/main/cantileverbeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
F=3000
a=5000
E=2*10**5
I=81958913.70
b=0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
h=(F*a**3/(3*E*I))/(1+(3*b/(2*a)))
print(h)
# Out:
# 7.625772131237996

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Smax=(307.2/2)*F*a/I
print(Smax)
# Out:
# 28.111646384595748
